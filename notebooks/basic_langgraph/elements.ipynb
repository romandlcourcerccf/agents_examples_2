# %% [markdown]
# ### State is a shared data structure that holds the current information or context of an appliction. In the case of Langgraph state defined by typed dict structure.

# %%
from typing import TypedDict

class Movie(TypedDict):
    name: str
    year: int

movie = Movie(name='Lacky number Slevin', year=2005) 
movie
# Out:
# {'name': 'Lacky number Slevin', 'year': 2005}

# %% [markdown]
# ### Nodes are individual functions that perform specific tasks within the graph.

# %%
def calc_days_from_relese(state: Movie):
